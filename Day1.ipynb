# %% [markdown]
# # BASICS

# %% [markdown]
# # Heading1

# %% [markdown]
# ## Heading2

# %% [markdown]
# ### Heading3

# %% [markdown]
# #### Heading4

# %% [markdown]
# ##### Heading5

# %% [markdown]
# ###### Heading6

# %% [markdown]
# # *hello*

# %% [markdown]
# # **welcome**

# %% [markdown]
# - python
# - pandas
# - numpy

# %% [markdown]
# * hii
# * hello
# * welcome

# %% [markdown]
# 1. hi
# 2. hello
# 3. vanakkam

# %% [markdown]
# ```print("hi")```

# %% [markdown]
# ` print("hi") `

# %% [markdown]
# ----------------------------

# %% [markdown]
# name | course | mark

# %% [markdown]
# | name | course | mark |
# | ---  | ---    | ---  |
# | raja | aiml | 85 |

# %%
# %time sum(range(100))
# Out:
# CPU times: total: 0 ns
# Wall time: 190 μs
# 4950

# %%
# %%time

total=0
for i in range(100):
    total+=i

# %pwd
# %history
# Out:
# %%time
#
# total=0
# for i in range(100):
#     total+=i
#
# %pwd
# %history
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# %%writefile sample.py
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.
